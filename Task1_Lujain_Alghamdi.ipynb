# %% [markdown]
# #Dataset Description

# %% [markdown]
# \
#
# ## The dataset contains information about road traffic accidents with the following columns:
#
# `Time`: Time of the accident
#
# `Day_of_week`: Day of the week when the accident occurred
#
# `Age_band_of_driver`: Age group of the driver
#
# `Sex_of_driver`: Gender of the driver
#
# `Educational_level`: Educational level of the driver
#
# `Vehicle_driver_relation`: Relationship of the driver to the vehicle
#
# `Driving_experience`: Driving experience of the driver
#
# `Type_of_vehicle`: Type of vehicle involved in the accident
#
# `Owner_of_vehicle`: Owner of the vehicle
#
# `Service_year_of_vehicle`: Service years of the vehicle
#
# `Area_accident_occured`: Area where the accident occurred
#
# `Lanes_or_Medians`: Lanes or medians at the accident site
#
# `Road_allignment`: Road alignment at the accident site
#
# `Types_of_Junction`: Type of junction at the accident site
#
# `Road_surface_type`: Type of road surface at the accident site
#
# `Road_surface_conditions`: Road surface conditions at the accident site
#
# `Light_conditions`: Light conditions at the time of the accident
#
# `Weather_conditions`: Weather conditions at the time of the accident
#
# `Type_of_collision`: Type of collision
#
# `Number_of_vehicles_involved`: Number of vehicles involved in the accident
#
# `Number_of_casualties`: Number of casualties in the accident
#
# `Vehicle_movement`: Movement of the vehicle during the accident
#
# `Casualty_class`: Class of casualty (driver, passenger, pedestrian)
#
# `Sex_of_casualty`: Gender of the casualty
#
# `Age_band_of_casualty`: Age group of the casualty
#
# `Casualty_severity`: Severity of the casualty
#
# `Work_of_casuality`: Occupation of the casualty
#
# `Fitness_of_casuality`: Fitness of the casualty
#
# `Pedestrian_movement`: Movement of the pedestrian
#
# `Cause_of_accident`: Cause of the accident
#
# `Accident_severity`: Severity of the accident

# %% [markdown]
# # Tasks

# %% [markdown]
# ##1. Data Cleaning

# %% [markdown]
# ### Read the dataset

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

df = pd.read_csv('/content/Task (1) Dataset.csv')

# %%
df.shape
# Out:
# (12316, 32)

# %%
df.head()
# Out:
#        Time Day_of_week Age_band_of_driver Sex_of_driver   Educational_level  \
# 0  17:02:00      Monday              18-30          Male   Above high school
# 1  17:02:00      Monday              31-50          Male  Junior high school
# 2  17:02:00      Monday              18-30          Male  Junior high school
# 3   1:06:00      Sunday              18-30          Male  Junior high school
# 4   1:06:00      Sunday              18-30          Male  Junior high school
#
#   Vehicle_driver_relation Driving_experience      Type_of_vehicle  \
# 0                Employee              1-2yr           Automobile
# 1                Employee         Above 10yr  Public (> 45 seats)
# 2                Employee              1-2yr      Lorry (41?100Q)
# 3                Employee             5-10yr  Public (> 45 seats)
# 4                Employee              2-5yr                  NaN
#
#   Owner_of_vehicle Service_year_of_vehicle  ... Vehicle_movement  \
# ...

# %%
df.tail()
# Out:
#            Time Day_of_week Age_band_of_driver Sex_of_driver  \
# 12311  16:15:00   Wednesday              31-50          Male
# 12312  18:00:00      Sunday            Unknown          Male
# 12313  13:55:00      Sunday            Over 51          Male
# 12314  13:55:00      Sunday              18-30        Female
# 12315  13:55:00      Sunday              18-30          Male
#
#         Educational_level Vehicle_driver_relation Driving_experience  \
# 12311                 NaN                Employee              2-5yr
# 12312   Elementary school                Employee             5-10yr
# 12313  Junior high school                Employee             5-10yr
# 12314  Junior high school                Employee         Above 10yr
# 12315  Junior high school                Employee             5-10yr
#
#        Type_of_vehicle Owner_of_vehicle Service_year_of_vehicle  ...  \
# 12311   Lorry (11?40Q)            Owner                     NaN  ...
# ...

# %%
df.sample(5)
# Out:
#           Time Day_of_week Age_band_of_driver Sex_of_driver  \
# 785    6:12:00    Saturday            Over 51       Unknown
# 4214  15:55:00      Monday              31-50          Male
# 5411   7:53:00      Friday           Under 18          Male
# 3183  19:26:00    Thursday              18-30          Male
# 2053   7:42:00    Thursday              18-30          Male
#
#        Educational_level Vehicle_driver_relation Driving_experience  \
# 785   Junior high school                Employee             5-10yr
# 4214  Junior high school                Employee              2-5yr
# 5411  Junior high school                Employee              1-2yr
# 3183  Junior high school                Employee             5-10yr
# 2053  Junior high school                Employee         Above 10yr
#
#           Type_of_vehicle Owner_of_vehicle Service_year_of_vehicle  ...  \
# 785   Public (> 45 seats)            Owner                  2-5yrs  ...
# ...

# %% [markdown]
# ### Handle Missing Values

# %%
df.isnull().sum()
# Out:
# Time                              0
# Day_of_week                       0
# Age_band_of_driver                0
# Sex_of_driver                     0
# Educational_level               741
# Vehicle_driver_relation         579
# Driving_experience              829
# Type_of_vehicle                 950
# Owner_of_vehicle                482
# Service_year_of_vehicle        3928
# Defect_of_vehicle              4427
# Area_accident_occured           239
# Lanes_or_Medians                385
# Road_allignment                 142
# Types_of_Junction               887
# Road_surface_type               172
# Road_surface_conditions           0
# Light_conditions                  0
# Weather_conditions                0
# Type_of_collision               155
# Number_of_vehicles_involved       0
# Number_of_casualties              0
# Vehicle_movement                308
# Casualty_class                    0
# Sex_of_casualty                   0
# Age_band_of_casualty              0
# ...

# %%
df = df.drop(['Casualty_class', 'Age_band_of_casualty',	'Casualty_severity'], axis=1)

# %%
df.dropna(subset=['Road_allignment'], inplace=True)

# %%
df.dropna(subset=['Road_surface_type'], inplace=True)

# %%
df.dropna(subset=['Type_of_collision'], inplace=True)

# %%
df = df.astype({'Educational_level':'str'})

# %%
df['Vehicle_driver_relation'] = df['Vehicle_driver_relation'].fillna(df['Vehicle_driver_relation'].mode().iloc[0])

# %%
df.isnull().sum()
# Out:
# Time                             0
# Day_of_week                      0
# Age_band_of_driver               0
# Sex_of_driver                    0
# Educational_level                0
# Vehicle_driver_relation          0
# Driving_experience               0
# Type_of_vehicle                  0
# Owner_of_vehicle               423
# Area_accident_occured          216
# Lanes_or_Medians               352
# Road_allignment                  0
# Types_of_Junction              845
# Road_surface_type                0
# Road_surface_conditions          0
# Light_conditions                 0
# Weather_conditions               0
# Type_of_collision                0
# Number_of_vehicles_involved      0
# Number_of_casualties             0
# Vehicle_movement               295
# Casualty_class                   0
# Sex_of_casualty                  0
# Age_band_of_casualty             0
# Casualty_severity                0
# Pedestrian_movement              0
# Cause_of_accident                0
# ...

# %%
df['Driving_experience'] = df['Driving_experience'].fillna(df['Driving_experience'].mode()).iloc[0])

# %%
df['Type_of_vehicle'] = df['Type_of_vehicle'].fillna(df['Type_of_vehicle'].mode().iloc[0])

# %%
df['Owner_of_vehicle'] = df['Owner_of_vehicle'].fillna(df['Owner_of_vehicle'].mode().iloc[0])

# %%
df['Area_accident_occured'] = df['Area_accident_occured'].fillna(df['Area_accident_occured'].mode().iloc[0])

# %%
df['Lanes_or_Medians'] = df['Lanes_or_Medians'].fillna(df['Lanes_or_Medians'].mode().iloc[0])

# %%
df['Types_of_Junction'] = df['Types_of_Junction'].fillna(df['Types_of_Junction'].mode().iloc[0])

# %%
df['Vehicle_movement'] = df['Vehicle_movement'].fillna(df['Vehicle_movement'].mode().iloc[0])

# %%
df['Sex_of_casualty'] = df['Sex_of_casualty'].fillna(df['Sex_of_casualty'].mode().iloc[0])

# %%
df.isnull().sum()
# Out:
# Time                           0
# Day_of_week                    0
# Age_band_of_driver             0
# Sex_of_driver                  0
# Educational_level              0
# Vehicle_driver_relation        0
# Driving_experience             0
# Type_of_vehicle                0
# Owner_of_vehicle               0
# Area_accident_occured          0
# Lanes_or_Medians               0
# Road_allignment                0
# Types_of_Junction              0
# Road_surface_type              0
# Road_surface_conditions        0
# Light_conditions               0
# Weather_conditions             0
# Type_of_collision              0
# Number_of_vehicles_involved    0
# Number_of_casualties           0
# Vehicle_movement               0
# Pedestrian_movement            0
# Cause_of_accident              0
# Accident_severity              0
# dtype: int64

# %%
print(df['Type_of_vehicle'].str.split().str[0].unique())
# Out:
# ['Automobile' 'Public' 'Lorry' 'Long' 'Taxi' 'Pick' 'Stationwagen'
#  'Ridden' 'Other' 'Bajaj' 'Turbo' 'Motorcycle' 'Special' 'Bicycle']

# %% [markdown]
# ### Correct any inconsistent data entries.

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df.head()
# Out:
#        Time Day_of_week Age_band_of_driver Sex_of_driver   Educational_level  \
# 0  17:02:00      Monday              18-30          Male   Above high school
# 1  17:02:00      Monday              31-50          Male  Junior high school
# 3   1:06:00      Sunday              18-30          Male  Junior high school
# 4   1:06:00      Sunday              18-30          Male  Junior high school
# 7  17:20:00      Friday              18-30          Male  Junior high school
#
#   Vehicle_driver_relation Driving_experience      Type_of_vehicle  \
# 0                Employee              1-2yr           Automobile
# 1                Employee         Above 10yr  Public (> 45 seats)
# 3                Employee             5-10yr  Public (> 45 seats)
# 4                Employee              2-5yr           Automobile
# 7                Employee              2-5yr           Automobile
#
#   Owner_of_vehicle Area_accident_occured  ... Road_surface_conditions  \
# ...

# %% [markdown]
# ### Ensure data types are appropriate for each column.
#
# ---

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 11853 entries, 0 to 12315
# Data columns (total 24 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   Time                         11853 non-null  object
#  1   Day_of_week                  11853 non-null  object
#  2   Age_band_of_driver           11853 non-null  object
#  3   Sex_of_driver                11853 non-null  object
#  4   Educational_level            11853 non-null  object
#  5   Vehicle_driver_relation      11853 non-null  object
#  6   Driving_experience           11853 non-null  object
#  7   Type_of_vehicle              11853 non-null  object
#  8   Owner_of_vehicle             11853 non-null  object
#  9   Area_accident_occured        11853 non-null  object
#  10  Lanes_or_Medians             11853 non-null  object
#  11  Road_allignment              11853 non-null  object
#  12  Types_of_Junction            11853 non-null  object
# ...

# %% [markdown]
# ## 2. Exploratory Data Analysis (EDA)

# %% [markdown]
# ### Perform summary statistics on the dataset.

# %%
df.describe()
# Out:
#        Number_of_vehicles_involved  Number_of_casualties
# count                 11853.000000          11853.000000
# mean                      2.041508              1.550156
# std                       0.688950              1.007122
# min                       1.000000              1.000000
# 25%                       2.000000              1.000000
# 50%                       2.000000              1.000000
# 75%                       2.000000              2.000000
# max                       7.000000              8.000000

# %%
df.head()
# Out:
#        Time Day_of_week Age_band_of_driver Sex_of_driver   Educational_level  \
# 0  17:02:00      Monday              18-30          Male   Above high school
# 1  17:02:00      Monday              31-50          Male  Junior high school
# 3   1:06:00      Sunday              18-30          Male  Junior high school
# 4   1:06:00      Sunday              18-30          Male  Junior high school
# 7  17:20:00      Friday              18-30          Male  Junior high school
#
#   Vehicle_driver_relation Driving_experience      Type_of_vehicle  \
# 0                Employee              1-2yr           Automobile
# 1                Employee         Above 10yr  Public (> 45 seats)
# 3                Employee             5-10yr  Public (> 45 seats)
# 4                Employee              2-5yr           Automobile
# 7                Employee              2-5yr           Automobile
#
#   Owner_of_vehicle Area_accident_occured  ... Road_surface_conditions  \
# ...

# %%
df['Number_of_vehicles_involved'].max()
# Out:
# 7

# %%
df['Number_of_casualties'].min()
# Out:
# 1

# %% [markdown]
# ### Identify and analyze patterns in the data.

# %%
sns.countplot(data=df)
# Out:
# <Axes: ylabel='count'>

# %% [markdown]
# ### Visualize the distribution of key variables (e.g., Age_band_of_driver, Type_of_vehicle).

# %%
plt.figure(figsize=(6, 2))
plt.hist(df['Vehicle_driver_relation'])
plt.xlabel('Vehicle_driver_relation')
plt.ylabel('count')
plt.title('Distribution of Vehicle_driver_relation')
plt.show()

# %%
plt.figure(figsize=(6, 2))
plt.hist(df['Sex_of_driver'])
plt.xlabel('Sex_of_driver')
plt.ylabel('Driving_experience')
plt.title('Distribution of Sex of driver and Driving experience ')
plt.show()

# %% [markdown]
# ### Explore relationships between variables (e.g., Age_band_of_driver vs. Accident_severity).

# %%
plt.figure(figsize=(8, 4))
plt.pie(df['Age_band_of_driver'].value_counts(), labels=df['Age_band_of_driver'].value_counts().index, autopct='%1.1f%%')
plt.title('Age Band of Driver')
plt.show()

# %% [markdown]
# ## 3. Data Visualization

# %% [markdown]
# * Ensure the visualizations are clear and informative.

# %% [markdown]
# ### Create visualizations to illustrate the findings from the EDA.

# %%
plt.figure(figsize=(6,4))
plt.bar(df['Area_accident_occured'].value_counts().index, df['Area_accident_occured'].value_counts())
# Out:
# <BarContainer object of 14 artists>

# %%
sns.boxenplot(df['Weather_conditions'])
# Out:
# <Axes: ylabel='Weather_conditions'>

# %% [markdown]
# ### Use appropriate plots such as histograms, bar charts, pie charts, scatter plots, and heatmaps.

# %%
plt.figure(figsize=(8, 4))
plt.pie(df['Light_conditions'].value_counts(), labels=df['Light_conditions'].value_counts().index, autopct='%1.1f%%')
plt.show()

# %% [markdown]
# ## 4. Insights and Conclusions

# %% [markdown]
# * <h3>Summarize the key insights gained from the data analysis.<h3/>
# * <h3>Draw conclusions based on the patterns observed in the data.<h3/>

# %%
# The pie chart shows that 33.2% of drivers are aged 31-50, 34.6% are aged 18-30 , 7.6% under 18yo , 12,6% unknown, and 12.9 over 51.
# Female drivers have less experience compared to male drivers.
# There no outliers in the dataset.
# Most of vehicle drive are employee
# Most driving conditions occurred in Daylight, accounting for 71.4% of the cases.
